# %%
# %reload_ext nb_black

# %%
import warnings

import pandas as pd
import numpy as np
import pickle

import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor
from scipy.cluster.hierarchy import dendrogram, linkage
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import AgglomerativeClustering, KMeans, DBSCAN
from sklearn.mixture import GaussianMixture
from sklearn.decomposition import PCA
from sklearn import datasets, metrics

import seaborn as sns
import matplotlib.pyplot as plt

# %%
def print_vif(x):
    """Utility for checking multicollinearity assumption
    
    :param x: input features to check using VIF. This is assumed to be a pandas.DataFrame
    :return: nothing is returned the VIFs are printed as a pandas series
    """
    # Silence numpy FutureWarning about .ptp
    with warnings.catch_warnings():
        warnings.simplefilter("ignore")
        x = sm.add_constant(x)

    vifs = []
    for i in range(x.shape[1]):
        vif = variance_inflation_factor(x.values, i)
        vifs.append(vif)

    print("VIF results\n-------------------------------")
    print(pd.Series(vifs, index=x.columns))
    print("-------------------------------\n")

# %%
df = pd.read_csv("../data/features_3_sec.csv")
df["genre"] = df["filename"].str.split(".").str[0]
df["songname"] = df["filename"].str.split(".").str[:2].str.join(".")

# %%
keep_cols = [
    #     "chroma_stft_mean",
    #     "chroma_stft_var",
    #     "rms_var",
    #     "zero_crossing_rate_mean",
    #     "zero_crossing_rate_var",
    #     "harmony_mean",
    #     "harmony_var",
    #     "perceptr_mean",
    #     "tempo",
    "mfcc1_mean",
    "mfcc2_mean",
    "mfcc2_var",
    "mfcc3_mean",
    "mfcc3_var",
    "mfcc4_mean",
    "mfcc4_var",
    "mfcc5_var",
    "mfcc6_mean",
    "mfcc6_var",
    "mfcc7_mean",
    "mfcc8_mean",
    "mfcc8_var",
    "mfcc9_mean",
    "mfcc9_var",
    "mfcc10_var",
    "mfcc12_mean",
    "mfcc12_var",
    "mfcc13_mean",
    "mfcc15_mean",
    "mfcc15_var",
    "mfcc16_mean",
    "mfcc16_var",
    "mfcc17_mean",
    "mfcc18_mean",
    "mfcc19_mean",
    "mfcc19_var",
    "mfcc20_mean",
    "mfcc20_var",
]

# %%
X = df[keep_cols]
y = df["genre"]

# %%
X_logged = X.copy()
for c in X_logged:
    if c.endswith("_var"):
        X_logged[c] = np.log(X_logged[c])

# %%
scaler = StandardScaler()
std_X = scaler.fit_transform(X)

# %%
clst = GaussianMixture(n_components=10)
# clst = DBSCAN(eps=3.5, min_samples=11, n_jobs=-1)
# clst = AgglomerativeClustering(n_clusters=10, affinity="cosine", linkage="complete")
# clst = KMeans(n_clusters=10, n_jobs=-1,)
clusters = clst.fit_predict(std_X)
df["cluster"] = clusters

# %%
pd.Series(clusters).value_counts()
# Out:
# 2    1700
# 7    1625
# 9    1295
# 1    1163
# 3    1016
# 5    1014
# 4     863
# 8     609
# 0     471
# 6     234
# dtype: int64

# %%
means_df = pd.DataFrame(scaler.inverse_transform(clst.means_), columns=X.columns).T
# means_df = pd.DataFrame(
#     scaler.inverse_transform(clst.cluster_centers_), columns=X.columns
# ).T
means_df.style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_e6f5863e_042a_11eb_abba_7085c2a9ca7arow0_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_e6f5863e_042a_11eb_abba_7085c2a9ca7arow0_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_e6f5863e_042a_11eb_abba_7085c2a9ca7arow0_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_e6f5863e_042a_11eb_abba_7085c2a9ca7arow0_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_e6f5863e_042a_11eb_abba_7085c2a9ca7arow0_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_e6f5863e_042a_11eb_abba_7085c2a9ca7arow0_col5 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_e6f5863e_042a_11eb_abba_7085c2a9ca7arow0_col6 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_e6f5863e_042a_11eb_abba_7085c2a9ca7arow0_col7 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_e6f5863e_042a_11eb_abba_7085c2a9ca7arow0_col8 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_e6f5863e_042a_11eb_abba_7085c2a9ca7arow0_col9 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_e6f5863e_042a_11eb_abba_7085c2a9ca7arow1_col0 {
#             background-color:  #b1c2de;
#             color:  #000000;
#         }    #T_e6f5863e_042a_11eb_abba_7085c2a9ca7arow1_col1 {
#             background-color:  #e0deed;
#             color:  #000000;
#         }    #T_e6f5863e_042a_11eb_abba_7085c2a9ca7arow1_col2 {
#             background-color:  #80aed2;
#             color:  #000000;
#         }    #T_e6f5863e_042a_11eb_abba_7085c2a9ca7arow1_col3 {
#             background-color:  #2685bb;
#             color:  #000000;
#         }    #T_e6f5863e_042a_11eb_abba_7085c2a9ca7arow1_col4 {
#             background-color:  #5a9ec9;
#             color:  #000000;
#         }    #T_e6f5863e_042a_11eb_abba_7085c2a9ca7arow1_col5 {
#             background-color:  #c8cde4;
#             color:  #000000;
#         }    #T_e6f5863e_042a_11eb_abba_7085c2a9ca7arow1_col6 {
#             background-color:  #b8c6e0;
#             color:  #000000;
#         }    #T_e6f5863e_042a_11eb_abba_7085c2a9ca7arow1_col7 {
#             background-color:  #b7c5df;
#             color:  #000000;
#         }    #T_e6f5863e_042a_11eb_abba_7085c2a9ca7arow1_col8 {
#             background-color:  #d5d5e8;
#             color:  #000000;
#         }    #T_e6f5863e_042a_11eb_abba_7085c2a9ca7arow1_col9 {
#             background-color:  #d1d2e6;
#             color:  #000000;
#         }    #T_e6f5863e_042a_11eb_abba_7085c2a9ca7arow2_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_e6f5863e_042a_11eb_abba_7085c2a9ca7arow2_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_e6f5863e_042a_11eb_abba_7085c2a9ca7arow2_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_e6f5863e_042a_11eb_abba_7085c2a9ca7arow2_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_e6f5863e_042a_11eb_abba_7085c2a9ca7arow2_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_e6f5863e_042a_11eb_abba_7085c2a9ca7arow2_col5 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_e6f5863e_042a_11eb_abba_7085c2a9ca7arow2_col6 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_e6f5863e_042a_11eb_abba_7085c2a9ca7arow2_col7 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_e6f5863e_042a_11eb_abba_7085c2a9ca7arow2_col8 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_e6f5863e_042a_11eb_abba_7085c2a9ca7arow2_col9 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_e6f5863e_042a_11eb_abba_7085c2a9ca7arow3_col0 {
#             background-color:  #dbdaeb;
#             color:  #000000;
#         }    #T_e6f5863e_042a_11eb_abba_7085c2a9ca7arow3_col1 {
#             background-color:  #efe9f3;
#             color:  #000000;
#         }    #T_e6f5863e_042a_11eb_abba_7085c2a9ca7arow3_col2 {
#             background-color:  #ede7f2;
#             color:  #000000;
#         }    #T_e6f5863e_042a_11eb_abba_7085c2a9ca7arow3_col3 {
#             background-color:  #99b8d8;
#             color:  #000000;
#         }    #T_e6f5863e_042a_11eb_abba_7085c2a9ca7arow3_col4 {
#             background-color:  #adc1dd;
#             color:  #000000;
#         }    #T_e6f5863e_042a_11eb_abba_7085c2a9ca7arow3_col5 {
#             background-color:  #e2dfee;
#             color:  #000000;
#         }    #T_e6f5863e_042a_11eb_abba_7085c2a9ca7arow3_col6 {
#             background-color:  #d7d6e9;
#             color:  #000000;
#         }    #T_e6f5863e_042a_11eb_abba_7085c2a9ca7arow3_col7 {
#             background-color:  #e5e1ef;
#             color:  #000000;
#         }    #T_e6f5863e_042a_11eb_abba_7085c2a9ca7arow3_col8 {
#             background-color:  #e7e3f0;
#             color:  #000000;
#         }    #T_e6f5863e_042a_11eb_abba_7085c2a9ca7arow3_col9 {
#             background-color:  #ede8f3;
#             color:  #000000;
#         }    #T_e6f5863e_042a_11eb_abba_7085c2a9ca7arow4_col0 {
#             background-color:  #589ec8;
#             color:  #000000;
#         }    #T_e6f5863e_042a_11eb_abba_7085c2a9ca7arow4_col1 {
#             background-color:  #2182b9;
#             color:  #000000;
#         }    #T_e6f5863e_042a_11eb_abba_7085c2a9ca7arow4_col2 {
#             background-color:  #056ba9;
#             color:  #f1f1f1;
#         }    #T_e6f5863e_042a_11eb_abba_7085c2a9ca7arow4_col3 {
#             background-color:  #056ead;
#             color:  #f1f1f1;
#         }    #T_e6f5863e_042a_11eb_abba_7085c2a9ca7arow4_col4 {
#             background-color:  #0569a4;
#             color:  #f1f1f1;
#         }    #T_e6f5863e_042a_11eb_abba_7085c2a9ca7arow4_col5 {
#             background-color:  #348ebf;
#             color:  #000000;
#         }    #T_e6f5863e_042a_11eb_abba_7085c2a9ca7arow4_col6 {
#             background-color:  #5a9ec9;
#             color:  #000000;
#         }    #T_e6f5863e_042a_11eb_abba_7085c2a9ca7arow4_col7 {
#             background-color:  #056faf;
#             color:  #f1f1f1;
#         }    #T_e6f5863e_042a_11eb_abba_7085c2a9ca7arow4_col8 {
#             background-color:  #05659f;
#             color:  #f1f1f1;
#         }    #T_e6f5863e_042a_11eb_abba_7085c2a9ca7arow4_col9 {
#             background-color:  #2786bb;
#             color:  #000000;
#         }    #T_e6f5863e_042a_11eb_abba_7085c2a9ca7arow5_col0 {
#             background-color:  #ced0e6;
#             color:  #000000;
#         }    #T_e6f5863e_042a_11eb_abba_7085c2a9ca7arow5_col1 {
#             background-color:  #ede8f3;
#             color:  #000000;
#         }    #T_e6f5863e_042a_11eb_abba_7085c2a9ca7arow5_col2 {
#             background-color:  #acc0dd;
#             color:  #000000;
#         }    #T_e6f5863e_042a_11eb_abba_7085c2a9ca7arow5_col3 {
#             background-color:  #76aad0;
#             color:  #000000;
#         }    #T_e6f5863e_042a_11eb_abba_7085c2a9ca7arow5_col4 {
#             background-color:  #94b6d7;
#             color:  #000000;
#         }    #T_e6f5863e_042a_11eb_abba_7085c2a9ca7arow5_col5 {
#             background-color:  #dad9ea;
#             color:  #000000;
#         }    #T_e6f5863e_042a_11eb_abba_7085c2a9ca7arow5_col6 {
#             background-color:  #cdd0e5;
#             color:  #000000;
#         }    #T_e6f5863e_042a_11eb_abba_7085c2a9ca7arow5_col7 {
#             background-color:  #d2d2e7;
#             color:  #000000;
#         }    #T_e6f5863e_042a_11eb_abba_7085c2a9ca7arow5_col8 {
#             background-color:  #e0deed;
#             color:  #000000;
#         }    #T_e6f5863e_042a_11eb_abba_7085c2a9ca7arow5_col9 {
#             background-color:  #e5e1ef;
#             color:  #000000;

# %%
print(pd.crosstab(clusters, y))
# Out:
# genre  blues  classical  country  disco  hiphop  jazz  metal  pop  reggae  \
# row_0
# 0        156         15      148      3       6    13     19   17      46
# 1          1          1       94    108     190    31      0  494     200
# 2        235          2       74    209     108     6    763    0      16
# 3         46        399       44     17      10   377     49   15       3
# 4         57        390       28     41      15   234     14   34      22
# 5        107         61      145     57     141   143      5   52     220
# 6         14         97       12      4       0    51      8   38       5
# 7        248          1      242    260     238    30    111    0     274
# 8        136         13       62     24     125    39      8   55     119
# 9          0         19      148    276     165    76     23  295      95
#
# genre  rock
# row_0
# 0        48
# 1        44
# 2       287
# 3        56
# 4        28
# 5        83
# 6         5
# 7       221
# 8        28
# 9       198

# %%
df[df["cluster"] == 6][100:150]
# Out:
#                  filename  length  chroma_stft_mean  chroma_stft_var  \
# 2370  country.00037.5.wav   66149          0.330232         0.082878
# 2372  country.00037.7.wav   66149          0.384266         0.083647
# 2395  country.00040.0.wav   66149          0.401978         0.088664
# 2409  country.00041.4.wav   66149          0.401592         0.084197
# 2410  country.00041.5.wav   66149          0.372751         0.082503
# 2411  country.00041.6.wav   66149          0.388089         0.086669
# 2412  country.00041.7.wav   66149          0.365553         0.084290
# 2437  country.00044.2.wav   66149          0.414964         0.084031
# 2438  country.00044.3.wav   66149          0.291293         0.088386
# 2440  country.00044.5.wav   66149          0.349176         0.080785
# 2442  country.00044.7.wav   66149          0.323878         0.085442
# 2443  country.00044.8.wav   66149          0.392832         0.079316
# 2444  country.00044.9.wav   66149          0.371546         0.079289
# 2445  country.00045.0.wav   66149          0.421631         0.095613
# 2447  country.00045.2.wav   66149          0.312951         0.089475
# 2449  country.00045.4.wav   66149          0.391695         0.092066
# 2452  country.00045.7.wav   66149          0.341726         0.091461
# 2475  country.00048.0.wav   66149          0.315974         0.089305
# 2476  country.00048.1.wav   66149          0.335088         0.094714
# 2482  country.00048.7.wav   66149          0.325141         0.092699
# 2629  country.00063.4.wav   66149          0.350312         0.082651
# 2686  country.00069.1.wav   66149          0.369672         0.082633
# 2687  country.00069.2.wav   66149          0.353980         0.085866
# 2688  country.00069.3.wav   66149          0.391914         0.081672
# 2693  country.00069.8.wav   66149          0.355801         0.088577
# 2995    disco.00000.0.wav   66149          0.468208         0.082209
# 2998    disco.00000.3.wav   66149          0.426549         0.088997
# 3001    disco.00000.6.wav   66149          0.424344         0.084245
# 3002    disco.00000.7.wav   66149          0.424434         0.088511
# 3003    disco.00000.8.wav   66149          0.465599         0.083535
# 3004    disco.00000.9.wav   66149          0.470072         0.086265
# 3027    disco.00003.2.wav   66149          0.449891         0.080482
# 3028    disco.00003.3.wav   66149          0.526017         0.076112
# 3028  0.198462  0.002148             3085.814277           9.469916e+05
# 3029  0.191999  0.002620             2875.528289           1.006012e+06
# 3055  0.163472  0.002962             2846.339553           1.779459e+05
# 3072  0.153346  0.004998             3124.454040           4.051102e+05
# 3074  0.177390  0.003237             3105.603523           3.995514e+05
# 3075  0.172740  0.009063             2778.955939           4.188755e+05
# 3079  0.181653  0.006067             2764.848745           6.224238e+05
# 3080  0.175324  0.006802             2542.514010           2.666761e+05
# 3081  0.193891  0.005670             2927.754960           2.565926e+05
# 3116  0.185200  0.002869             2797.690446           4.228895e+05
# 3119  0.191595  0.004197             2814.313448           4.176978e+05
# 3121  0.171315  0.003883             2715.976670           7.727638e+05
# 3122  0.178364  0.002688             2796.879846           6.364562e+05
# 3123  0.185011  0.002939             2607.895224           2.355826e+05
# 3124  0.182736  0.003809             2594.998142           3.687224e+05
# 3165  0.112850  0.003228             2799.870450           1.237834e+06
# 3174  0.116209  0.001679             3176.848205           4.611002e+05
# 3175  0.115114  0.001975             3072.401067           4.920939e+05
#
#       spectral_bandwidth_mean  spectral_bandwidth_var  ...  mfcc18_mean  \
# 2370              2503.685955           181798.257431  ...    -4.462796
# 2372              2356.729081           261155.543811  ...    -4.639517
# 2395              2738.594643           154334.410749  ...    -3.400161
# 2409              2927.146752           211648.885202  ...    -8.206468
# 2410              2923.235637           289494.654567  ...    -4.757769
# 2411              2790.481373           265956.976715  ...    -5.286162
# 2412              2858.141108           174252.353387  ...    -9.512616
# 2437              1818.877496           443946.044007  ...     3.121540
# 2438              2714.346339           110427.695082  ...    -5.624926
# 2440              2360.604816            98695.241095  ...    -0.406148
# 2442              2594.634903           272358.976527  ...    -3.268896
# 2443              2141.759211           281327.444219  ...     4.613228
# 2444              2225.614122           174509.717507  ...     1.816263
# 2445              2510.805387           152596.625257  ...    -2.539033
# 2447              2729.182251           134124.642227  ...    -1.253412
# 2449              2453.839529           183893.260115  ...    -0.387979
# 2452              2685.125895           145668.000702  ...     2.434045
# 2475              2458.237140           190714.043866  ...    -1.959029
# 2476              2463.215259           255636.138774  ...    -2.792213
# 2482              2421.988455           251935.005753  ...    -4.471817
# 2629              1577.032006           385816.997519  ...     6.619775
# 2686              1573.911976            34571.121357  ...   -12.910322
# 2687              1624.492371           103644.021040  ...    -1.743740
# 2688              1510.728207            70816.654080  ...     5.040407
# 2693              1585.413815            83019.241415  ...    -0.401805
# 2995              2694.307257           152158.675714  ...    -1.321193
# 2998              2517.169846           203999.203058  ...     2.196682
# 3001              2452.851365           205503.752803  ...     0.155997
# 3002              2517.673518           202855.011563  ...     0.836997
# 3003              2574.737659           181518.483628  ...     3.867977
# 3004              2638.923021           186214.324485  ...     1.915601
# 3027              2627.850428           160533.541048  ...    -0.848349
# 3028              2817.696667           109412.129136  ...    -2.765218
# 3029              2757.021422           150817.555161  ...    -4.211623
# 3055              2500.799311            91221.602443  ...    -3.935595
# 3027   48.149895    -3.094605   58.700806    -0.803807   65.075676    disco
# 3028   61.322002    -4.812472   56.248032    -1.368116   77.979309    disco
# 3029   34.182331    -2.415235   66.605553     2.691403   45.211418    disco
# 3055   35.766731    -6.576159   26.750713    -0.242148   24.093700    disco
# 3072   63.717625     3.236939   66.683517     7.697007   64.819969    disco
# 3074   94.058434     9.695928  121.034241     2.186644  136.600693    disco
# 3075   71.790833    -1.716234   69.148064     1.377041   63.822334    disco
# 3079   41.101223     1.603445   52.004402     3.397058   51.370773    disco
# 3080   47.487038    -0.174606   76.518471     3.491128   71.406792    disco
# 3081   69.542519    -0.347624   46.297436    -2.290542   58.801186    disco
# 3116   87.172157     0.191210   48.187996     0.783684   69.176102    disco
# 3119   98.321342     1.640698   94.256912     2.976822   84.488747    disco
# 3121   41.002480    -1.401376   28.794315     2.014270   39.884892    disco
# 3122  122.941635    -0.530069   61.964336    -2.155666  105.299652    disco
# 3123  187.077789     0.607588   92.209404     3.549273  115.443642    disco
# 3124   22.257608     0.842421   29.924511     4.266058   40.117809    disco
# 3165   41.902931    -0.946036   58.845779    -0.476718   40.361076    disco
# 3174   33.753914     0.331383   48.535538    -0.746576   47.210800    disco
# 3175   41.181602     1.250791   40.761951    -1.512832   45.484596    disco
#
#         genre       songname  cluster
# 2370  country  country.00037        2
# 2372  country  country.00037        2
# 2395  country  country.00040        2
# 2409  country  country.00041        2
# 2410  country  country.00041        2
# 2411  country  country.00041        2
# 2412  country  country.00041        2
# 2437  country  country.00044        2
# 2438  country  country.00044        2
# 2440  country  country.00044        2
# 2442  country  country.00044        2
# 2443  country  country.00044        2
# 2444  country  country.00044        2
# 2445  country  country.00045        2
# 2447  country  country.00045        2
# 2449  country  country.00045        2
# 2452  country  country.00045        2
# 2475  country  country.00048        2
# 2476  country  country.00048        2
# 2482  country  country.00048        2
# 2629  country  country.00063        2
# 2686  country  country.00069        2
# 2687  country  country.00069        2
# 2688  country  country.00069        2
# 2693  country  country.00069        2
# 2995    disco    disco.00000        2
# 2998    disco    disco.00000        2
# 3001    disco    disco.00000        2
# 3002    disco    disco.00000        2
# 3003    disco    disco.00000        2
# 3004    disco    disco.00000        2
# 3027    disco    disco.00003        2
# 3028    disco    disco.00003        2
# 3029    disco    disco.00003        2
# 3055    disco    disco.00006        2
# 3072    disco    disco.00007        2
# 3074    disco    disco.00007        2
# 3075    disco    disco.00008        2
# 3079    disco    disco.00008        2
# 3080    disco    disco.00008        2
# 3081    disco    disco.00008        2
# 3116    disco    disco.00012        2
# 3119    disco    disco.00012        2
# 3121    disco    disco.00012        2
# 3122    disco    disco.00012        2
# 3123    disco    disco.00012        2
# 3124    disco    disco.00012        2
# 3165    disco    disco.00017        2
# 3174    disco    disco.00018        2
# 3175    disco    disco.00018        2
#
# [50 rows x 63 columns]
